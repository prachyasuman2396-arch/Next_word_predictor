# %%
faqs = """I am someone who lives quietly on the surface and intensely underneath. From the outside, I might look like another student, another learner, another face in the crowd—but inside, there is a constant motion, a mind that rarely rests, a hunger to understand how things work, why they work, and how they can be made better.
I have always been drawn to complexity. Simple answers never satisfied me. As a child, I didn’t just want to know what something was—I wanted to know how it came to be, what it was made of, and what would happen if one small part of it changed. That curiosity never left; it only grew sharper with time.
I learned early that discipline matters more than motivation. Motivation is loud but unreliable. Discipline is quiet and stubborn—it shows up even when excitement fades. That belief shaped how I study, how I work, and how I plan my future. I don’t wait to feel ready. I start, and I become ready along the way.
I am a student of Computer Science, but more than that, I am a student of systems—systems of code, systems of thought, systems of people. I enjoy breaking large problems into smaller ones, understanding the role of each component, and rebuilding the whole thing in a cleaner, more efficient way. Whether it’s an algorithm, a neural network, or a life decision, my approach remains the same: analyze, understand, optimize.
There are days when learning feels effortless, when concepts click instantly and everything seems aligned. And then there are days when nothing makes sense—when bugs refuse to disappear, when logic fails, when progress feels invisible. On those days, I don’t quit. I slow down. I re-read. I re-think. I remind myself that mastery is built in moments no one sees.
I am ambitious, but not careless. I don’t chase shortcuts. I believe that real confidence comes from knowing that you’ve done the hard work—that even if no one applauds, you are improving. Every subject I study, every project I build, every skill I practice is a brick in something much larger: a future where I am capable, independent, and impactful.
Technology fascinates me because it rewards clarity. Computers don’t care about excuses. They don’t respond to half-efforts. They demand precision, and in return, they give power—the power to create, to automate, to solve problems at scale. That honesty is something I deeply respect.
I am especially drawn to areas where logic meets real-world consequence—machine learning, cybersecurity, systems architecture. These fields are not just about writing code; they’re about responsibility. A small mistake can mean failure. A well-designed solution can mean efficiency, safety, or even trust. I want to be someone whose work can be trusted.
I don’t measure success by comparison. I measure it by alignment—whether my actions match my goals, whether today’s effort is slightly better than yesterday’s. I know I am not perfect. I procrastinate sometimes. I overthink often. I set high standards and then feel frustrated when I don’t meet them immediately. But I also know this: I do not give up on myself.
I value depth over noise. I would rather understand one concept thoroughly than skim through ten. I prefer quiet progress over loud announcements. I don’t need constant validation; I need growth. And when I finally speak about what I know, I want my words to carry weight.
There is a future version of me that I am slowly becoming—more skilled, more confident, more grounded. Every late night spent studying, every concept revisited, every failure analyzed instead of avoided is a step toward that version. I don’t rush the process, but I respect it.
I believe that consistency beats talent when talent gets comfortable. I believe that learning never truly ends. I believe that intelligence is not just the ability to understand, but the willingness to keep learning even when it’s uncomfortable.
At my core, I am someone who wants to build—systems, solutions, a meaningful career, and a life that reflects effort and integrity. I may still be learning, still growing, still figuring things out, but I am moving forward. And I trust that motion.
This is not the story of someone who arrived.
This is the story of someone becoming.
"""

# %%
import numpy as np
import pandas as pd

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
token = Tokenizer()
token.fit_on_texts([faqs])

# %%
len(token.word_index)
# Out:
# 362

# %%
input =[]
for sentance in faqs.split('\n'):
  tokens = token.texts_to_sequences([sentance])[0]

  for i in range(1, len(tokens)):
    input.append(tokens[:i+1])

# %%
max_len = max([len(x) for x in input])

# %%
max_len
# Out:
# 69

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input = pad_sequences(input, maxlen=max_len, padding='pre')

# %%
padded_input
# Out:
# array([[  0,   0,   0, ...,   0,   1,   9],
#        [  0,   0,   0, ...,   1,   9,  18],
#        [  0,   0,   0, ...,   9,  18,  36],
#        ...,
#        [  0,   0,   0, ...,   6,  98,   8],
#        [  0,   0,   0, ...,  98,   8,  18],
#        [  0,   0,   0, ...,   8,  18, 362]], dtype=int32)

# %%
x = padded_input[:,:-1]
y = padded_input[:,-1]

# %%
x.shape
# Out:
# (695, 68)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense,Dropout
from tensorflow.keras.regularizers import l2

# %%
model = Sequential()
vocab_size = len(token.word_index) + 1
model.add(Embedding(vocab_size,100,embeddings_regularizer=l2(1e-6),input_length=max_len-1))
model.add(LSTM(250,activation = 'tanh',recurrent_regularizer=l2(1e-6), return_sequences=True))
model.add(Dropout(0.2))



model.add(LSTM(150,activation='tanh',recurrent_regularizer=l2(1e-6), return_sequences=True))
model.add(Dropout(0.2))



model.add(LSTM(100,activation='tanh',recurrent_regularizer=l2(1e-6)))


model.add(Dense(vocab_size,activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_10 (Embedding)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_30 (LSTM)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_31 (LSTM)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_32 (LSTM)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x, y, epochs = 100)
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.0313 - loss: 5.8533
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0704 - loss: 5.5043
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0740 - loss: 5.4198
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0708 - loss: 5.3713
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0796 - loss: 5.3461
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0680 - loss: 5.3297
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0656 - loss: 5.3728
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0779 - loss: 5.2999
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0619 - loss: 5.4469
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0847 - loss: 5.3809
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0820 - loss: 5.2626
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0575 - loss: 5.4115
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0739 - loss: 5.4555
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0821 - loss: 5.3554
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0658 - loss: 5.3748
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0773 - loss: 5.3451
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0770 - loss: 5.3310
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0780 - loss: 5.3768
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0645 - loss: 5.2751
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0700 - loss: 5.1615
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0605 - loss: 5.1461
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0594 - loss: 5.1000
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0743 - loss: 4.9585
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0591 - loss: 4.8884
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0861 - loss: 4.7519
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1025 - loss: 4.6718
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1175 - loss: 4.5237
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1009 - loss: 4.4526
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1128 - loss: 4.3862
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1085 - loss: 4.3242
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1191 - loss: 4.2262
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1177 - loss: 4.1731
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1127 - loss: 4.0753
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1338 - loss: 3.9693
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1449 - loss: 3.8470
# Epoch 36/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1617 - loss: 3.8168
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1494 - loss: 3.7476
# Epoch 38/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1665 - loss: 3.6766
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1728 - loss: 3.6522
# Epoch 40/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1805 - loss: 3.5712
# Epoch 41/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1671 - loss: 3.5465
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1972 - loss: 3.5061
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2320 - loss: 3.4073
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.2324 - loss: 3.3611
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.2481 - loss: 3.3155
# Epoch 46/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.2575 - loss: 3.2554
# Epoch 47/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3001 - loss: 3.1643
# Epoch 48/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3000 - loss: 3.0896
# Epoch 49/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3202 - loss: 3.0702
# Epoch 50/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3195 - loss: 3.0420
# Epoch 51/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3550 - loss: 2.9612
# Epoch 52/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3505 - loss: 2.9268
# Epoch 53/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3702 - loss: 2.8423
# Epoch 54/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3572 - loss: 2.8629
# Epoch 55/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4049 - loss: 2.7762
# Epoch 56/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3943 - loss: 2.7339
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4632 - loss: 2.6480
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4639 - loss: 2.6164
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4485 - loss: 2.6236
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4498 - loss: 2.5434
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4852 - loss: 2.5180
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4954 - loss: 2.4422
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4974 - loss: 2.4388
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5229 - loss: 2.3948
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5364 - loss: 2.3413
# Epoch 66/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5849 - loss: 2.2265
# Epoch 67/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5704 - loss: 2.2600
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5815 - loss: 2.2372
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6105 - loss: 2.1346
# Epoch 70/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6020 - loss: 2.1386
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6205 - loss: 2.0145
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6567 - loss: 2.0511
# Epoch 73/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6432 - loss: 2.0129
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6406 - loss: 1.9739
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6565 - loss: 1.9837
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6877 - loss: 1.8813
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6812 - loss: 1.9069
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6759 - loss: 1.8699
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6838 - loss: 1.7910
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7126 - loss: 1.7320
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6966 - loss: 1.7371
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6943 - loss: 1.7369
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7347 - loss: 1.6703
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7327 - loss: 1.5961
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7164 - loss: 1.6338
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7465 - loss: 1.5566
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7639 - loss: 1.5064
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7796 - loss: 1.4745
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7713 - loss: 1.4653
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7421 - loss: 1.4681
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7942 - loss: 1.3850
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7873 - loss: 1.4067
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8101 - loss: 1.3558
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8034 - loss: 1.3519
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7883 - loss: 1.3493
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8386 - loss: 1.2805
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8183 - loss: 1.2833
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8124 - loss: 1.2831
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8192 - loss: 1.2179
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8429 - loss: 1.1678

# %%
import time
text = 'I am someone'
for i  in range(40):
  token_text = token.texts_to_sequences([text])[0]
  padded_text = pad_sequences([token_text],maxlen=max_len-1,padding='pre')
  output = model.predict(padded_text)
  output = np.argmax(output)
  for word,index in token.word_index.items():
    if index == output:
      text = text + ' ' + word
      break
  time.sleep(0.2)
  print(text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# I am someone who
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# I am someone who lives
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# I am someone who lives quietly
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# I am someone who lives quietly on
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# I am someone who lives quietly on the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# I am someone who lives quietly on the surface
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# I am someone who lives quietly on the surface to
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# I am someone who lives quietly on the surface to disappear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# I am someone who lives quietly on the surface to disappear and
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# I am someone who lives quietly on the surface to disappear and logic
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# I am someone who lives quietly on the surface to disappear and logic fails
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant validation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant validation i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant validation i need
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant validation i need look
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant validation i need look like
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant validation i need look like another
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant validation i need look like another student
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant validation i need look like another student another
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant validation i need look like another student another learner
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant validation i need look like another student another learner another
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant validation i need look like another student another learner another face
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant validation i need look like another student another learner another face in
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant validation i need look like another student another learner another face in the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant validation i need look like another student another learner another face in the crowd—but
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant validation i need look like another student another learner another face in the crowd—but inside
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# I am someone who lives quietly on the surface to disappear and logic fails to solve problems at scale that honesty is something i don’t need constant validation i need look like another student another learner another face in the crowd—but inside there

# %%
import pickle

data = {
    "model": model,
    "tokenizer": token,
    "max_len": max_len
}

with open("model.pkl", "wb") as f:
    pickle.dump(data, f)

print("Model, tokenizer and max_len saved successfully.")
# Out:
# Model, tokenizer and max_len saved successfully.
